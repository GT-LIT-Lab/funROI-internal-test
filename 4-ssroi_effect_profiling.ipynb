# %% [markdown]
# The notebook estimates the effect sizes of the specific contrasts

# %%
# Import funROI

import sys
import os
package_path = "../funROI"
sys.path.append(os.path.abspath(package_path))
import funROI
from funROI import utils, first_level, analysis

from nilearn.plotting import plot_glass_brain

# %%
# Set the BIDS data directories
funROI.set_bids_data_folder("./data/bids")
funROI.set_bids_deriv_folder("./data/bids/derivatives")
funROI.set_bids_preprocessed_folder("./data/bids/derivatives/fmriprep")

# %%
# Can be used for evaluting the effects on the same task
effect_profiler = analysis.EffectProfiler(
    subject = '040',
    localizer_task = 'EventsOrig',
    localizer = 'Sent_Sem-Perc',
    effect_task = 'EventsOrig',
    effect_contrast = 'Perc_photo',
    parcels = 'Events',
    threshold_type = 'percent',
    threshold_value = 0.1
)
effect_profiler.run()
# Out:
# /Users/ruimingao/Documents/funROI/funROI/analysis.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_splits = pd.concat([results_splits, pd.DataFrame({'ssroi': ssroi, 'n_voxels': np.sum(ssroi_mask), 'split': split_i, 'mean_effect_size': mean_effect_size}, index=[0])], ignore_index=True)
#     ssroi  n_voxels  mean_effect_size
# 0     2.0       178          1.843260
# 1     4.0       116          0.263657
# 2     6.0        46         -0.490677
# 3     8.0       107          1.057184
# 4    10.0        98         -0.003557
# 5    12.0       125         -0.467456
# 6    14.0       181          0.146595
# 7    16.0        65          0.296354
# 8    18.0        55          1.148216
# 9    20.0       118          0.462499
# ...

# %%
# Can be used for evaluting the effects on a different task
effect_profiler = analysis.EffectProfiler(
    subject = '199',
    localizer_task = 'Events2move',
    localizer = 'Sent_Sem-Perc',
    effect_task = 'langlocSN',
    effect_contrast = 'S',
    parcels = 'Events',
    threshold_type = 'percent',
    threshold_value = 0.1
)
effect_profiler.run()
# Out:
# /Users/ruimingao/Documents/funROI/funROI/analysis.py:193: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_splits = pd.concat([results_splits, pd.DataFrame({'ssroi': ssroi, 'n_voxels': np.sum(ssroi_mask), 'split': split_i, 'mean_effect_size': mean_effect_size}, index=[0])], ignore_index=True)
#     ssroi  n_voxels  mean_effect_size
# 0     2.0       178          2.362965
# 1     4.0       116          0.410535
# 2     6.0        46          1.249223
# 3     8.0       107          1.587745
# 4    10.0        98          0.251259
# 5    12.0       125          1.004737
# 6    14.0       181          0.665531
# 7    16.0        65          2.082095
# 8    18.0        55          1.079494
# 9    20.0       118          0.619516
# ...
