# %%
import sys
import os
import glob

package_path = "../../funROI"
sys.path.append(os.path.abspath(package_path))
import funROI

funROI.set_bids_data_folder("../data/bids")
funROI.set_bids_deriv_folder("../data/bids/derivatives/funROI")
funROI.set_bids_preprocessed_folder("../data/bids/derivatives/fmriprep")

# Turn off all warnings
import warnings

warnings.filterwarnings("ignore")

use_spm_smooth = True

# %% [markdown]
# # SPM First-Level Migration

# %% [markdown]
# The replication is based on SPM first-level (contrast) results to mitigate any
#
# possible discrepancies originating from the first-level modeling choices. The
#
# code below migrates the SPM first-level results to a BIDS-compliant file
#
# structure, which will be used in the subsequent analyses.

# %%
# from funROI.first_level.spm import migrate_first_level_from_spm

# spm_data_dir = '../data/spm_first_level_results'
# for task, task_suffix in [
#     ('SWNloc', 'SWNlocIPS168_3runs'),
#     ('EventsOrig', 'EventsOrig_instrsep_2runs')]:
#     spm_folders = glob.glob(os.path.join(spm_data_dir, f'*_{task_suffix}'))
#     for spm_folder in spm_folders:
#         subject_id = os.path.basename(spm_folder).split('_')[0]
#         migrate_first_level_from_spm(spm_folder, subject_id, task)

# %%
# test orthogonality by design matrix
subject = "087"
task = "SWNloc"

from funROI.utils import get_design_matrix

design_matrix = get_design_matrix(subject, task)

# %% [markdown]
# # Parcels Generation

# %%
from funROI.analysis import ParcelsGenerator
from nilearn.plotting import plot_glass_brain

# %% [markdown]
# ## Parcels generation with S-N language localizer

# %%
parcels_generator = ParcelsGenerator(
    smoothing_kernel_size=6, overlap_thr_vox=0.1, use_spm_smooth=use_spm_smooth
)
parcels_generator.add_subjects(
    subjects=[
        "040",
        "057",
        "059",
        "056",
        "067",
        "068",
        "019",
        "070",
        "087",
        "078",
        "089",
        "076",
    ],
    task="SWNloc",
    localizer="S-N",
    threshold_type="none",
    threshold_value=0.001,
)
parcels = parcels_generator.generate()
plot_glass_brain(parcels, plot_abs=False)
parcels_generator.save(parcels_name="languageSminusN")

# %%
thresholded_parcels = parcels_generator.select(
    min_voxel_size=0, overlap_thr_roi=0.5
)
plot_glass_brain(thresholded_parcels, plot_abs=False)
# Out:
# [ 1.  2.  3.  4.  6.  7.  8.  9. 10. 13.]
# Remaining parcels: 10

# %% [markdown]
# ## Parcels generation with Events localizers

# %%
parcels_generator_photo = ParcelsGenerator(
    smoothing_kernel_size=6,
    overlap_thr_vox=0.1,
    use_spm_smooth=use_spm_smooth,
)
parcels_generator_photo.add_subjects(
    subjects=[
        "040",
        "057",
        "059",
        "056",
        "067",
        "068",
        "019",
        "070",
        "087",
        "078",
        "089",
        "076",
    ],
    task="EventsOrig",
    localizer="Sem_photominusPerc_photo",
    threshold_type="none",
    threshold_value=0.05,
)
parcels = parcels_generator_photo.generate()
plot_glass_brain(parcels, plot_abs=False)
parcels_generator_photo.save(parcels_name="eventsPhoto")

# %%
parcels_generator_sent = ParcelsGenerator(
    smoothing_kernel_size=6,
    overlap_thr_vox=0.1,
    use_spm_smooth=use_spm_smooth,
)
parcels_generator_sent.add_subjects(
    subjects=[
        "040",
        "057",
        "059",
        "056",
        "067",
        "068",
        "019",
        "070",
        "087",
        "078",
        "089",
        "076",
    ],
    task="EventsOrig",
    localizer="Sem_sentminusPerc_sent",
    threshold_type="none",
    threshold_value=0.05,
)
parcels = parcels_generator_sent.generate()
plot_glass_brain(parcels, plot_abs=False)
parcels_generator_sent.save(parcels_name="eventsSent")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       1 parcels_generator_sent = ParcelsGenerator(
#       2     smoothing_kernel_size=6,
#       3     overlap_thr_vox=0.1,
#       4     use_spm_smooth=use_spm_smooth,
#       5 )
# ----> 6 parcels_generator_sent.add_subjects(
#       7     subjects=[
#       8         "040",
#       9         "057",
#      10         "059",
#      11         "056",
#      12         "067",
#      13         "068",
#      14         "019",
#      15         "070",
#      16         "087",
#      17         "078",
#      18         "089",
#      19         "076",
#      20     ],
#      21     task="EventsOrig",
#      22     localizer="Sem_sentminusPerc_sent",
#      23     threshold_type="none",
#      24     threshold_value=0.05,
#      25 )
#      26 parcels = parcels_generator_sent.generate()
#      27 plot_glass_brain(parcels, plot_abs=False)
#
# File ~/Documents/funROI_all/funROI/funROI/analysis/parcels_generator.py:74, in ParcelsGenerator.add_subjects(self, subjects, task, localizer, threshold_type, threshold_value)
#      58 """
#      59 Add subjects and localizers for ROI parcellation.
#      60
#    (...)
#      68     Localizer name or Localizer object.
#      69 """
#      70 self.info.append(
#      71     (subjects, task, localizer, threshold_type, threshold_value)
#      72 )
# ---> 74 localizer_maps = get_localizers(
#      75     subjects, task, localizer, threshold_type, threshold_value
#      76 )
#      78 self._data.extend(localizer_maps)
#      80 binary_masks = []
#
# File ~/Documents/funROI_all/funROI/funROI/localizer.py:160, in get_localizers(subjects, task, localizer, threshold_type, threshold_value)
#     155         localizer_info = localizer._asdict()
#     156 assert (
#     157     localizer_info is not None
#     158 ), f"Localizer {localizer} not found for subject {subject}."
# --> 160 p_maps = get_contrasts_orth_single_task(
#     161     subject, task, localizer_info["contrasts"], "p"
#     162 )
#     163 masks = create_p_map_mask(
#     164     p_maps,
#     165     localizer_info["conjunctionType"],
#     166     threshold_type,
#     167     threshold_value,
#     168 )
#     169 data.append(masks)
#
# File ~/Documents/funROI_all/funROI/funROI/contrast.py:165, in get_contrasts_orth_single_task(subject, task, contrasts, type)
#     161     img = create_contrast(
#     162         subject, task, f"orth{run}", contrast, type
#     163     )
#     164 else:
# --> 165     img = load_img(contrast_path)
#     166 flattened_data = img.get_fdata().flatten()
#     167 data_contrast.append(flattened_data)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nilearn/image/image.py:1392, in load_img(img, wildcards, dtype)
#    1355 def load_img(img, wildcards=True, dtype=None):
#    1356     """Load a Niimg-like object from filenames or list of filenames.
#    1357
#    1358     .. versionadded:: 0.2.5
#    (...)
#    1390
#    1391     """
# -> 1392     return check_niimg(img, wildcards=wildcards, dtype=dtype)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nilearn/_utils/niimg_conversions.py:315, in check_niimg(niimg, ensure_ndim, atleast_4d, dtype, return_iterator, wildcards)
#     310     return ni.image.concat_imgs(
#     311         niimg, ensure_ndim=ensure_ndim, dtype=dtype
#     312     )
#     314 # Otherwise, it should be a filename or a SpatialImage, we load it
# --> 315 niimg = load_niimg(niimg, dtype=dtype)
#     317 if ensure_ndim == 3 and len(niimg.shape) == 4 and niimg.shape[3] == 1:
#     318     # "squeeze" the image.
#     319     data = safe_get_data(niimg)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nilearn/_utils/niimg.py:135, in load_niimg(niimg, dtype)
#     128 elif not isinstance(niimg, nibabel.spatialimages.SpatialImage):
#     129     raise TypeError(
#     130         "Data given cannot be loaded because it is"
#     131         " not compatible with nibabel format:\n"
#     132         + _repr_niimgs(niimg, shorten=True)
#     133     )
# --> 135 dtype = _get_target_dtype(_get_data(niimg).dtype, dtype)
#     137 if dtype is not None:
#     138     # Copyheader and set dtype in header if header exists
#     139     if niimg.header is not None:
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nilearn/_utils/niimg.py:25, in _get_data(img)
#      23 if img._data_cache is not None:
#      24     return img._data_cache
# ---> 25 data = np.asanyarray(img._dataobj)
#      26 img._data_cache = data
#      27 return data
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nibabel/arrayproxy.py:457, in ArrayProxy.__array__(self, dtype)
#     436 def __array__(self, dtype=None):
#     437     """Read data from file and apply scaling, casting to ``dtype``
#     438
#     439     If ``dtype`` is unspecified, the dtype of the returned array is the
#    (...)
#     455         Scaled image data with type `dtype`.
#     456     """
# --> 457     arr = self._get_scaled(dtype=dtype, slicer=())
#     458     if dtype is not None:
#     459         arr = arr.astype(dtype, copy=False)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nibabel/arrayproxy.py:424, in ArrayProxy._get_scaled(self, dtype, slicer)
#     422     scl_inter = scl_inter.astype(use_dtype)
#     423 # Read array and upcast as necessary for big slopes, intercepts
# --> 424 scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     425 if dtype is not None:
#     426     scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nibabel/arrayproxy.py:394, in ArrayProxy._get_unscaled(self, slicer)
#     390 if canonical_slicers(slicer, self._shape, False) == canonical_slicers(
#     391     (), self._shape, False
#     392 ):
#     393     with self._get_fileobj() as fileobj, self._lock:
# --> 394         return array_from_file(
#     395             self._shape,
#     396             self._dtype,
#     397             fileobj,
#     398             offset=self._offset,
#     399             order=self.order,
#     400             mmap=self._mmap,
#     401         )
#     402 with self._get_fileobj() as fileobj:
#     403     return fileslice(
#     404         fileobj,
#     405         slicer,
#    (...)
#     410         lock=self._lock,
#     411     )
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/site-packages/nibabel/volumeutils.py:465, in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     463 if hasattr(infile, 'readinto'):
#     464     data_bytes = bytearray(n_bytes)
# --> 465     n_read = infile.readinto(data_bytes)
#     466     needs_copy = False
#     467 else:
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/gzip.py:324, in GzipFile.read(self, size)
#     322     import errno
#     323     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 324 return self._buffer.read(size)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /opt/homebrew/anaconda3/envs/funROI/lib/python3.12/gzip.py:537, in _GzipReader.read(self, size)
#     535     uncompress = self._decompressor.decompress(buf, size)
#     536 else:
# --> 537     uncompress = self._decompressor.decompress(b"", size)
#     539 if self._decompressor.unused_data != b"":
#     540     # Prepend the already read bytes to the fileobj so they can
#     541     # be seen by _read_eof() and _read_gzip_header()
#     542     self._fp.prepend(self._decompressor.unused_data)
#
# KeyboardInterrupt:

# %%
from funROI.localizer import Localizer

parcels_generator_both = ParcelsGenerator(
    smoothing_kernel_size=6,
    overlap_thr_vox=0.1,
    use_spm_smooth=use_spm_smooth,
)
parcels_generator_both.add_subjects(
    subjects=[
        "040",
        "057",
        "059",
        "056",
        "067",
        "068",
        "019",
        "070",
        "087",
        "078",
        "089",
        "076",
    ],
    task="EventsOrig",
    localizer=Localizer(
        localizer="SemMinusPercBoth",
        contrasts=["Sem_photominusPerc_photo", "Sem_sentminusPerc_sent"],
        conjunctionType="and",
    ),
    threshold_type="none",
    threshold_value=0.05,
)
parcels = parcels_generator_both.generate()
plot_glass_brain(parcels, plot_abs=False)
parcels_generator_both.save(parcels_name="eventsBoth")

# %% [markdown]
# The localizer is also registered for subjects selected after the codes are run.

# %% [markdown]
# # Comparison of funROI vs. spm_ss results

# %%
# Load spm_ss results
from pathlib import Path
from nilearn.image import load_img, new_img_like

spm_ss_folder = Path.cwd().parent / "data" / "spm_ss_results"
sent_localized_parcels = load_img(
    spm_ss_folder / "parcels_Sem_sentminusPerc_sent_2024-10-16" / "fROIs.nii"
)
plot_glass_brain(
    sent_localized_parcels,
    plot_abs=False,
    title="Sem_sentminusPerc_sent spm_ss",
)
photo_localized_parcels = load_img(
    spm_ss_folder / "parcels_Sem_photominusPerc_photo_2024-10-16" / "fROIs.nii"
)
plot_glass_brain(
    photo_localized_parcels,
    plot_abs=False,
    title="Sem_photominusPerc_photo spm_ss",
)
both_localized_parcels = load_img(
    (
        spm_ss_folder
        / "parcels_Sem_sentminusSem_photo_and_Sem_sentminusPerc_sent_2024-10-16"
        / "fROIs.nii"
    )
)
plot_glass_brain(
    both_localized_parcels, plot_abs=False, title="Both contrasts spm_ss"
)
SminuN_localized_parcels = load_img(
    spm_ss_folder / "parcels_S-N_2024-10-23" / "fROIs.nii"
)
plot_glass_brain(SminuN_localized_parcels, plot_abs=False, title="S-N spm_ss")

# %%
from funROI.utils import get_parcels

languageSminusN = get_parcels("languageSminusN")
eventsPhoto = get_parcels("eventsPhoto")
eventsSent = get_parcels("eventsSent")
eventsBoth = get_parcels("eventsBoth")

# %%
from matplotlib import pyplot as plt


def plot_diff(spm_ss_parcels, funroi_parcels, title):
    plot_glass_brain(spm_ss_parcels, plot_abs=False, title=title + " spm_ss")
    plot_glass_brain(funroi_parcels, plot_abs=False, title=title + " funROI")
    spm_ss_parcels_binary = spm_ss_parcels.get_fdata() != 0
    funroi_parcels_binary = funroi_parcels.get_fdata() != 0
    diff = spm_ss_parcels_binary.astype(int) - funroi_parcels_binary.astype(
        int
    )
    plot_glass_brain(
        new_img_like(spm_ss_parcels, diff),
        plot_abs=False,
        title=title + " spm_ss - funROI",
        colorbar=True,
        cmap="coolwarm",
        vmax=1,
        vmin=-1,
        threshold=0,
    )
    print(f"spm_ss voxels n: {spm_ss_parcels_binary.sum()}")
    print(f"funroi voxels n: {funroi_parcels_binary.sum()}")
    print(
        f"intersection: {(spm_ss_parcels_binary & funroi_parcels_binary).sum()} ({(spm_ss_parcels_binary & funroi_parcels_binary).sum() / spm_ss_parcels_binary.sum() * 100:.2f}%)"
    )

# %%
plot_diff(SminuN_localized_parcels, languageSminusN, "S-N contrast")
plot_diff(sent_localized_parcels, eventsSent, "Sent Sem-Perc contrast")
plot_diff(photo_localized_parcels, eventsPhoto, "Photo Sem-Perc contrast")
plot_diff(both_localized_parcels, eventsBoth, "Both Sem-Perc contrasts")
# Out:
# spm_ss voxels n: 4375
# funroi voxels n: 4375
# intersection: 4375 (100.00%)
# spm_ss voxels n: 31429
# funroi voxels n: 31429
# intersection: 31429 (100.00%)
# spm_ss voxels n: 32122
# funroi voxels n: 32120
# intersection: 32120 (99.99%)
# spm_ss voxels n: 7271
# funroi voxels n: 7271
# intersection: 7271 (100.00%)
